# %%
import nmresearch as nmr
import numpy as np
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From C:\Users\awsta\Documents\qeg-workspace\qeg-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
import os, sys

class HiddenPrints:
    def __enter__(self):
        self._original_stdout = sys.stdout
        sys.stdout = open(os.devnull, 'w')

    def __exit__(self, exc_type, exc_val, exc_tb):
        sys.stdout.close()
        sys.stdout = self._original_stdout

# %%
ensemble_signal = {}
time_vec = np.arange(0,5,.05)

# %%
N = 4
ham = nmr.Hamiltonian(N)
#ham.H_cs_scrambling()
operator =  nmr.PauliMatrix(N)
sigz = (1/2**(N/2))*nmr.lanczos.op_basis.vec(operator.sigmaZ(0))
#solver = nmr.Lanczos(ham.to_super(),sigz)

# %%
num_trials = 300
signals = np.zeros((num_trials, len(time_vec)))

for idx in range(num_trials):
    ham.clear()
    ham.H_cs_scrambling()
    solver = nmr.Lanczos(ham.to_super(),sigz)
    if (idx+1) % 30 == 0:
        print(str(idx/num_trials * 100) + "% done")
    with HiddenPrints():
        solver.compute_lanczos_fast()

    signals[idx] = solver.auto_correlation(time_vec)
    del solver
# Out:
# C:\Users\awsta\AppData\Local\Temp\ipykernel_15972\3736870097.py:13: ComplexWarning: Casting complex values to real discards the imaginary part
#   signals[idx] = solver.auto_correlation(time_vec)
# 9.666666666666666% done
# 19.666666666666664% done
# 29.666666666666668% done
# 39.666666666666664% done
# 49.666666666666664% done
# 59.66666666666667% done
# 69.66666666666667% done
# 79.66666666666666% done
# 89.66666666666666% done
# 99.66666666666667% done

# %%
ensemble_signal[N] = (np.mean(signals,0), np.std(signals,0))

# %%
plt.errorbar(time_vec, np.mean(signals,0),np.std(signals,0),label="300 averages",errorevery=5)
plt.hlines(0.25,0,5,'k','dashed', label="y=0.25 assymptote")
plt.xlabel("time")
plt.ylabel("sigma-z auto-correlation")
plt.title("Ensemble NV auto-correlation, N = " + str(N))
plt.legend()
plt.show()

# %%
N = 5
ham = nmr.Hamiltonian(N)
#ham.H_cs_scrambling()
operator =  nmr.PauliMatrix(N)
sigz = (1/2**(N/2))*nmr.lanczos.op_basis.vec(operator.sigmaZ(0))
#solver = nmr.Lanczos(ham.to_super(),sigz)

num_trials = 300
signals = np.zeros((num_trials, len(time_vec)))

for idx in range(num_trials):
    ham.clear()
    ham.H_cs_scrambling()
    solver = nmr.Lanczos(ham.to_super(),sigz)
    if (idx+1) % 30 == 0:
        print(str(idx/num_trials * 100) + "% done")
    with HiddenPrints():
        solver.compute_lanczos_fast()

    signals[idx] = solver.auto_correlation(time_vec)
    del solver

ensemble_signal[N] = (np.mean(signals,0), np.std(signals,0))

plt.errorbar(time_vec, np.mean(signals,0),np.std(signals,0),label="300 averages",errorevery=5)
plt.hlines(0.25,0,5,'k','dashed', label="y=0.25 assymptote")
plt.xlabel("time")
plt.ylabel("sigma-z auto-correlation")
plt.title("Ensemble NV auto-correlation, N = " + str(N))
plt.legend()
plt.show()
# Out:
# C:\Users\awsta\AppData\Local\Temp\ipykernel_15972\950572808.py:20: ComplexWarning: Casting complex values to real discards the imaginary part
#   signals[idx] = solver.auto_correlation(time_vec)
# 9.666666666666666% done
# 19.666666666666664% done
# 29.666666666666668% done
# 39.666666666666664% done
# 49.666666666666664% done
# 59.66666666666667% done
# 69.66666666666667% done
# 79.66666666666666% done
# 89.66666666666666% done
# 99.66666666666667% done

# %%
N = 6
ham = nmr.Hamiltonian(N)
#ham.H_cs_scrambling()
operator =  nmr.PauliMatrix(N)
sigz = (1/2**(N/2))*nmr.lanczos.op_basis.vec(operator.sigmaZ(0))
#solver = nmr.Lanczos(ham.to_super(),sigz)

num_trials = 300
signals = np.zeros((num_trials, len(time_vec)))

for idx in range(num_trials):
    ham.clear()
    ham.H_cs_scrambling()
    solver = nmr.Lanczos(ham.to_super(),sigz)
    if (idx+1) % 30 == 0:
        print(str(idx/num_trials * 100) + "% done")
    with HiddenPrints():
        solver.compute_lanczos_fast()

    signals[idx] = solver.auto_correlation(time_vec)
    del solver

ensemble_signal[N] = (np.mean(signals,0), np.std(signals,0))

plt.errorbar(time_vec, np.mean(signals,0),np.std(signals,0),label="300 averages",errorevery=5)
plt.hlines(0.25,0,5,'k','dashed', label="y=0.25 assymptote")
plt.xlabel("time")
plt.ylabel("sigma-z auto-correlation")
plt.title("Ensemble NV auto-correlation, N = " + str(N))
plt.legend()
plt.show()
# Out:
# C:\Users\awsta\AppData\Local\Temp\ipykernel_15972\659003282.py:20: ComplexWarning: Casting complex values to real discards the imaginary part
#   signals[idx] = solver.auto_correlation(time_vec)
# 9.666666666666666% done
# 19.666666666666664% done
# 29.666666666666668% done
# 39.666666666666664% done
# 49.666666666666664% done
# 59.66666666666667% done
# 69.66666666666667% done
# 79.66666666666666% done
# 89.66666666666666% done
# 99.66666666666667% done

# %%
N = 7
ham = nmr.Hamiltonian(N)
#ham.H_cs_scrambling()
operator =  nmr.PauliMatrix(N)
sigz = (1/2**(N/2))*nmr.lanczos.op_basis.vec(operator.sigmaZ(0))
#solver = nmr.Lanczos(ham.to_super(),sigz)

num_trials = 300
signals = np.zeros((num_trials, len(time_vec)))

for idx in range(num_trials):
    ham.clear()
    ham.H_cs_scrambling()
    solver = nmr.Lanczos(ham.to_super(),sigz)
    if (idx+1) % 30 == 0:
        print(str(idx/num_trials * 100) + "% done")
    with HiddenPrints():
        solver.compute_lanczos_fast()

    signals[idx] = solver.auto_correlation(time_vec)
    del solver

ensemble_signal[N] = (np.mean(signals,0), np.std(signals,0))

plt.errorbar(time_vec, np.mean(signals,0),np.std(signals,0),label="300 averages",errorevery=5)
plt.hlines(0.25,0,5,'k','dashed', label="y=0.25 assymptote")
plt.xlabel("time")
plt.ylabel("sigma-z auto-correlation")
plt.title("Ensemble NV auto-correlation, N = " + str(N))
plt.legend()
plt.show()
# Out:
# C:\Users\awsta\AppData\Local\Temp\ipykernel_15972\2012118028.py:20: ComplexWarning: Casting complex values to real discards the imaginary part
#   signals[idx] = solver.auto_correlation(time_vec)
# 9.666666666666666% done
# 19.666666666666664% done
# 29.666666666666668% done
# 39.666666666666664% done
# 49.666666666666664% done
# 59.66666666666667% done
# 69.66666666666667% done
# 79.66666666666666% done
# 89.66666666666666% done
# 99.66666666666667% done

# %%
N = 8
ham = nmr.Hamiltonian(N)
#ham.H_cs_scrambling()
operator =  nmr.PauliMatrix(N)
sigz = (1/2**(N/2))*nmr.lanczos.op_basis.vec(operator.sigmaZ(0))
#solver = nmr.Lanczos(ham.to_super(),sigz)

num_trials = 300
signals = np.zeros((num_trials, len(time_vec)))

for idx in range(num_trials):
    ham.clear()
    ham.H_cs_scrambling()
    solver = nmr.Lanczos(ham.to_super(),sigz)
    if (idx+1) % 30 == 0:
        print(str(idx/num_trials * 100) + "% done")
    with HiddenPrints():
        solver.compute_lanczos_fast()

    signals[idx] = solver.auto_correlation(time_vec)
    del solver

ensemble_signal[N] = (np.mean(signals,0), np.std(signals,0))

plt.errorbar(time_vec, np.mean(signals,0),np.std(signals,0),label="300 averages",errorevery=5)
plt.hlines(0.25,0,5,'k','dashed', label="y=0.25 assymptote")
plt.xlabel("time")
plt.ylabel("sigma-z auto-correlation")
plt.title("Ensemble NV auto-correlation, N = " + str(N))
plt.legend()
plt.show()
# Out:
# C:\Users\awsta\AppData\Local\Temp\ipykernel_15972\998332799.py:20: ComplexWarning: Casting complex values to real discards the imaginary part
#   signals[idx] = solver.auto_correlation(time_vec)
# 9.666666666666666% done
# 19.666666666666664% done
# 29.666666666666668% done
# 39.666666666666664% done
# 49.666666666666664% done
# 59.66666666666667% done
# 69.66666666666667% done
# 79.66666666666666% done
# 89.66666666666666% done
# 99.66666666666667% done

# %%
N = 9
ham = nmr.Hamiltonian(N)
#ham.H_cs_scrambling()
operator =  nmr.PauliMatrix(N)
sigz = (1/2**(N/2))*nmr.lanczos.op_basis.vec(operator.sigmaZ(0))
#solver = nmr.Lanczos(ham.to_super(),sigz)

num_trials = 300
signals = np.zeros((num_trials, len(time_vec)))

for idx in range(num_trials):
    ham.clear()
    ham.H_cs_scrambling()
    solver = nmr.Lanczos(ham.to_super(),sigz)
    if (idx+1) % 30 == 0:
        print(str(idx/num_trials * 100) + "% done")
    with HiddenPrints():
        solver.compute_lanczos_fast()

    signals[idx] = solver.auto_correlation(time_vec)
    del solver

ensemble_signal[N] = (np.mean(signals,0), np.std(signals,0))

plt.errorbar(time_vec, np.mean(signals,0),np.std(signals,0),label="300 averages",errorevery=5)
plt.hlines(0.25,0,5,'k','dashed', label="y=0.25 assymptote")
plt.xlabel("time")
plt.ylabel("sigma-z auto-correlation")
plt.title("Ensemble NV auto-correlation, N = " + str(N))
plt.legend()
plt.show()
# Out:
# C:\Users\awsta\AppData\Local\Temp\ipykernel_15972\2405640404.py:20: ComplexWarning: Casting complex values to real discards the imaginary part
#   signals[idx] = solver.auto_correlation(time_vec)
# 9.666666666666666% done
# 19.666666666666664% done
# 29.666666666666668% done
# 39.666666666666664% done
# 49.666666666666664% done
# 59.66666666666667% done
# 69.66666666666667% done
# 79.66666666666666% done
# 89.66666666666666% done
# 99.66666666666667% done

# %%
N = 10
ham = nmr.Hamiltonian(N)
#ham.H_cs_scrambling()
operator =  nmr.PauliMatrix(N)
sigz = (1/2**(N/2))*nmr.lanczos.op_basis.vec(operator.sigmaZ(0))
#solver = nmr.Lanczos(ham.to_super(),sigz)

num_trials = 300
signals = np.zeros((num_trials, len(time_vec)))

for idx in range(num_trials):
    ham.clear()
    ham.H_cs_scrambling()
    solver = nmr.Lanczos(ham.to_super(),sigz)
    if (idx+1) % 30 == 0:
        print(str(idx/num_trials * 100) + "% done")
    with HiddenPrints():
        solver.compute_lanczos_fast()

    signals[idx] = solver.auto_correlation(time_vec)
    del solver

ensemble_signal[N] = (np.mean(signals,0), np.std(signals,0))

plt.errorbar(time_vec, np.mean(signals,0),np.std(signals,0),label="300 averages",errorevery=5)
plt.hlines(0.25,0,5,'k','dashed', label="y=0.25 assymptote")
plt.xlabel("time")
plt.ylabel("sigma-z auto-correlation")
plt.title("Ensemble NV auto-correlation, N = " + str(N))
plt.legend()
plt.show()
# Out:
# C:\Users\awsta\AppData\Local\Temp\ipykernel_15972\912593960.py:20: ComplexWarning: Casting complex values to real discards the imaginary part
#   signals[idx] = solver.auto_correlation(time_vec)
# 9.666666666666666% done
# 19.666666666666664% done
# 29.666666666666668% done
# 39.666666666666664% done
# 49.666666666666664% done
# 59.66666666666667% done
# 69.66666666666667% done
# 79.66666666666666% done
# 89.66666666666666% done
# 99.66666666666667% done

# %%
import pickle
with open('dont_run_me.dat', 'wb') as fi:
        pickle.dump(ensemble_signal, fi)

# %%
N = 11
ham = nmr.Hamiltonian(N)
#ham.H_cs_scrambling()
operator =  nmr.PauliMatrix(N)
sigz = (1/2**(N/2))*nmr.lanczos.op_basis.vec(operator.sigmaZ(0))
#solver = nmr.Lanczos(ham.to_super(),sigz)

num_trials = 300
signals = np.zeros((num_trials, len(time_vec)))

for idx in range(num_trials):
    ham.clear()
    ham.H_cs_scrambling()
    solver = nmr.Lanczos(ham.to_super(),sigz)
    if (idx+1) % 30 == 0:
        print(str(idx/num_trials * 100) + "% done")
    with HiddenPrints():
        solver.compute_lanczos_fast()

    signals[idx] = solver.auto_correlation(time_vec)
    del solver

ensemble_signal[N] = (np.mean(signals,0), np.std(signals,0))

plt.errorbar(time_vec, np.mean(signals,0),np.std(signals,0),label="300 averages",errorevery=5)
plt.hlines(0.25,0,5,'k','dashed', label="y=0.25 assymptote")
plt.xlabel("time")
plt.ylabel("sigma-z auto-correlation")
plt.title("Ensemble NV auto-correlation, N = " + str(N))
plt.legend()
plt.show()
# Out:
# C:\Users\awsta\AppData\Local\Temp\ipykernel_15820\1584790440.py:20: ComplexWarning: Casting complex values to real discards the imaginary part
#   signals[idx] = solver.auto_correlation(time_vec)
# 9.666666666666666% done
# 19.666666666666664% done
# 29.666666666666668% done
# 39.666666666666664% done
# 49.666666666666664% done
# 59.66666666666667% done
# 69.66666666666667% done
# 79.66666666666666% done
# 89.66666666666666% done
# 99.66666666666667% done

# %%
import pickle
with open('test2.dat', 'wb') as fi:
        pickle.dump(ensemble_signal, fi)
