# %%
import nmresearch as nmr
import matplotlib.pyplot as plt

# %%
#nmr.Experiment(122,folder='expt9').mqc(True)

# %%
print(nmr.PulseProgram.pine8(n_max=2, fc=9))
# Out:
# ph0 = (360) 0 18 216 234 72 90 288 306
# ph1 = (360) 189 207 45 63 261 279 117 135

# %%
print(nmr.PulseProgram.pine8_mqc(n_max=2, fc=10))
# Out:
# ph0 = (360) 0 200 220 60 80 280 300 140
# ph1 = (360) 10 210 230 70 90 290 310 150
#
# ph2 = (360) 170 10 30 230 250 90 110 310
# ph3 = (360) 180 20 40 240 260 100 120 320
#
# ;Increment encoding z-rotation
#
# 5m ph2*18
# 5m ph3*18
#
# ;increment frame change to account for longer evolution
#
# 5m ip2*80
# 5m ip3*80

# %%
3e-6
# Out:
# 3e-06

# %%
3*10**-6
# Out:
# 3e-06

# %%
12*3.6
# Out:
# 43.2

# %%
nmr.Experiment(139,folder='expt9').tpc(cycle=43)
# Out:
# array([ 1.00000000e+00,  5.31445328e-01,  8.00987731e-02,  1.41986264e-02,
#         4.08982175e-03,  1.38899606e-03,  3.08665792e-04,  3.08665792e-04,
#        -7.71664480e-04,  1.54332896e-04,  8.48830928e-04,  1.08033027e-03,
#         1.08033027e-03,  2.93232503e-03,  9.25997376e-04])

# %%
nmr.Experiment(140,folder='expt9').tpc(cycle=43)
# Out:
# array([ 1.00000000e+00, -2.31660232e-03,  7.87644788e-03,  5.40540541e-03,
#         2.39382239e-03,  9.26640927e-04, -1.54440154e-04,  1.08108108e-03,
#        -4.63320463e-04,  6.17760618e-04, -3.08880309e-04,  2.31660232e-03,
#         4.63320463e-04,  2.77992278e-03,  1.23552124e-03])

# %%
nmr.Experiment(144,folder='expt9').tpc(cycle=120)
# Out:
# C:\Users\awsta\Documents\workspace\qeg-env\lib\site-packages\nmrglue\fileio\bruker.py:394: UserWarning: Error reading the pulse program
#   warn('Error reading the pulse program')
# array([1.        , 0.41266019, 0.26120388, 0.1767767 , 0.11324272,
#        0.07673786, 0.05001942, 0.03401942, 0.02174757, 0.01537864,
#        0.00994175, 0.00807767, 0.00380583, 0.00466019, 0.0015534 ])

# %%
#pine8, no fc
nmr.Experiment(145,folder='expt9').tpc(cycle=4*12)
# Out:
# array([1.00000000e+00, 4.16938111e-01, 4.39739414e-02, 6.20443617e-03,
#        1.86133085e-03, 1.39599814e-03, 1.55110904e-04, 0.00000000e+00,
#        6.20443617e-04, 5.42888165e-04, 1.55110904e-04, 0.00000000e+00,
#        3.10221809e-04, 1.70621995e-03, 1.24088723e-03])

# %%
nmr.Experiment(146,folder='expt9').tpc(cycle=4*12)
# Out:
# array([ 1.00000000e+00, -3.24332713e-02,  1.24146493e-03,  3.41402855e-03,
#        -1.55183116e-04,  2.32774674e-03, -3.10366232e-04,  1.55183116e-03,
#        -1.55183116e-04,  1.08628181e-03, -6.20732464e-04,  1.24146493e-03,
#        -1.24146493e-03,  3.10366232e-03, -1.47423960e-03])

# %%
nmr.Experiment(147,folder='expt9').tpc(cycle=4*12)
# Out:
# array([ 1.        , -0.05188388,  0.00957381,  0.01621371,  0.01405188,
#         0.01204447,  0.00972823,  0.00934219,  0.00787523,  0.00818406,
#         0.00602224,  0.00555899,  0.00494132,  0.0056362 ,  0.00494132])

# %%
nmr.Experiment(185,folder='expt9').tpc(cycle=43,use_real=False)
# Out:
# array([ 1.00000000e+00,  4.22900604e-01,  4.51135653e-02,  6.98062096e-03,
#         1.87539071e-03, -1.25026047e-03,  1.04188373e-03, -1.66701396e-03,
#         7.29318608e-04,  1.14607210e-03, -3.12565118e-04,  3.12565118e-04,
#         1.04188373e-03,  4.16753490e-04,  2.08376745e-04])

# %%
nmr.Experiment(186,folder='expt9').tpc(cycle=43,use_real=False)
# Out:
# C:\Users\awsta\Documents\workspace\qeg-env\lib\site-packages\nmrglue\fileio\bruker.py:394: UserWarning: Error reading the pulse program
#   warn('Error reading the pulse program')
# array([ 1.00000000e+00,  6.16381112e-03,  4.59674049e-03,  1.67154200e-03,
#         1.04471375e-03,  1.14918512e-03, -5.22356874e-04, -8.35770999e-04,
#         1.98495612e-03,  1.04471375e-04,  5.22356874e-04, -4.17885499e-04,
#         5.22356874e-04, -3.13414125e-04,  1.46259925e-03])

# %%
data_new = nmr.Experiment(190,folder='expt9').tpc(cycle=43,use_real=False)

# %%
data_old = nmr.Experiment(191,folder='expt9').tpc(cycle=43,use_real=False)

# %%
plt.plot(data_new-data_old)
plt.show()

# %%
type(360/12) is not int
# Out:
# True

# %%
360/13 != int(360/13)
# Out:
# True

# %%
360/12
# Out:
# 30.0

# %%
for M in range(360):
    if 180/(M+1) == int(180/(M+1)):
        print(M+1)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 9
# 10
# 12
# 15
# 18
# 20
# 30
# 36
# 45
# 60
# 90
# 180
