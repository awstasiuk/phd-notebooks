# %%
import nmresearch as nmr
import numpy as np

# %%
s1 = nmr.Experiment(15,"expt9")
s2 = nmr.Experiment(16,"expt9")
s3 = nmr.Experiment(17,"expt9")

# %%
data1=s1.fid()
s1.nmr_dic['acqus']['_comments'][0]
# Out:
# '$$ 2023-10-30 15:09:53.940 -0400  LabUser@RLE-AB7E01640B1'

# %%
data2=s2.fid()
s2.nmr_dic['acqus']['_comments'][0]
# Out:
# '$$ 2023-10-30 15:10:11.846 -0400  LabUser@RLE-AB7E01640B1'

# %%
delay1 = 71.846-53.940

# %%
data3=s3.fid()
s3.nmr_dic['acqus']['_comments'][0]
# Out:
# '$$ 2023-10-30 15:15:26.596 -0400  LabUser@RLE-AB7E01640B1'

# %%
delay2 = 5*60+(26.596-11.846)

# %%
data1[0][0]
# Out:
# 6440.0

# %%
delay1
# Out:
# 17.906000000000006

# %%
data2[0][0]/data1[0][0]
# Out:
# 0.14177018633540373

# %%
-delay1/np.log(1-data2[0][0]/data1[0][0])
# Out:
# 117.12196244962813

# %%
delay2
# Out:
# 314.75

# %%
data3[0][0]/data1[0][0]
# Out:
# 0.7234472049689441

# %%
-delay2/np.log(1-data3[0][0]/data1[0][0])
# Out:
# 244.87426317457553
