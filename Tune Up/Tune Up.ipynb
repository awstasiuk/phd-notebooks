# %%
import nmresearch as nmr
import numpy as np
import scipy as sp

import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From C:\Users\awsta\Documents\qeg-workspace\qeg-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
N=1
s=1
m=1
A=1
J=N*m
MHz = 1e6
kHz = 1e3
ns = 1e-9
T = N/(A*m)
mu0 = 4*np.pi*1e-7 * (N/A**2)
hbar = 1.054571817 * 1e-34 * (J*s)
gammaF = 2*np.pi * 40.078 * (MHz/T)
gammaE = 2*np.pi * 28024.9514242 * (MHz/T)
gammaLi = 2*np.pi * 16.546 * (MHz/T)

theta=np.pi/2
a = 4.08
r0 = a*10**-10
spatial_part = (1-3*np.cos(theta)**2)/r0**3

Jf = (hbar/(2*np.pi)) * (mu0/ (4*np.pi)) * gammaF**2 * (10**10)**3
Je = (hbar/(2*np.pi)) * (mu0/ (4*np.pi)) * gammaE**2 * (10**9)**3
Jli = (hbar/(2*np.pi)) * (mu0/ (4*np.pi)) * gammaLi**2 * (10**10)**3
Jlif = (hbar/(2*np.pi)) * (mu0/ (4*np.pi)) * gammaLi*gammaF * (10**10)**3

# %%
Jf/kHz # J0 = 106.43 kHz * Ang**3
# Out:
# 106.43099224225564

# %%
Jli/kHz
# Out:
# 18.140199924781527

# %%
Jlif/kHz
# Out:
# 43.939497920064916

# %%
Jlif/kHz * (2/a)**3
# Out:
# 5.1756462823575715

# %%
(Jf/kHz) * (np.sqrt(2)/a)**3
# Out:
# 4.432335387060774

# %%
1/(Je/10**3)/ns
# Out:
# 19215.612571563892

# %%
nmr.Experiment(527, folder='expt9').calibrate90()
# Out:
# array index of max signal is 6

# %%
nmr.Experiment(529,folder='expt9').calibrate_framechange(offset=7,use_real=False)
# Out:
# C:\Users\awsta\Documents\qeg-workspace\qeg-env\lib\site-packages\nmrglue\fileio\bruker.py:394: UserWarning: Error reading the pulse program
#   warn('Error reading the pulse program')
# Over-rotation angle is given by 6 deg.

# %%
print(nmr.PulseProgram.disorder_fidelity_staber2_cal(fc=13,n_max=20))
# Out:
# 25m ip5*156
# 25m ip14*156
# 25m ip15*156
# 25m ip16*156
# 25m ip17*156
# 25m ip18*156
# 25m ip19*312
#
# ph0 = (360) 90 90 270 270 0 0 180 180
#
# ph1 = (360) 13 65 207 169 221 3 325 17 159 121 173 315 277 329 111 73 125 267 229 281 63 25 77 219 181 233 15 337 29 171 133 185 327 289 341 123 85 137 279 241 293 75 37 89 231 193 245 27 349 41 183 145 197 339 301 353 135 97 149 291
# ph2 = (360) 116 168 310 272 324 106 68 120 262 224 276 58 20 72 214 176 228 10 332 24 166 128 180 322 284 336 118 80 132 274 236 288 70 32 84 226 188 240 22 344 36 178 140 192 334 296 348 130 92 144 286 248 300 82 44 96 238 200 252 34
# ph3 = (360) 219 181 233 15 337 29 171 133 185 327 289 341 123 85 137 279 241 293 75 37 89 231 193 245 27 349 41 183 145 197 339 301 353 135 97 149 291 253 305 87 49 101 243 205 257 39 1 53 195 157 209 351 313 5 147 109 161 303 265 317
# ph4 = (360) 142 104 156 298 260 312 94 56 108 250 212 264 46 8 60 202 164 216 358 320 12 154 116 168 310 272 324 106 68 120 262 224 276 58 20 72 214 176 228 10 332 24 166 128 180 322 284 336 118 80 132 274 236 288 70 32 84 226 188 240
#
# ph5 = (360) 169 169 349 349 79 79 259 259
#
# ph14 = (360) 182 182 182 182 182 182 182 182
# ph2 = (360) 26 258 310 272 324 286 338 210 262 224 276 238 290 162 214 176 228 190 242 114 166 128 180 142 194 66 118 80 132 94 146 18 70 32 84 46 98 330 22 344 36 358 50 282 334 296 348 310 2 234 286 248 300 262 314 186 238 200 252 214 266 138 190 152 204 166 218 90 142 104 156 118 170 42 94 56 108 70 122 354 46 8 60 22 74 306 358 320 12 334 26 258 310 272 324 286 338 210 262 224 276 238 290 162 214 176 228 190 242 114 166 128 180 142 194 66 118 80 132 94 146 18 70 32 84 46 98 330 22 344 36 358 50 282 334 296 348 310 2 234 286 248 300 262 314 186 238 200 252 214 266 138 190 152 204 166 218 90 142 104 156 118 170 42 94 56 108 70 122 354 46 8 60 22 74 306 358 320 12 334 26 258 310 272 324 286 338 210 262 224 276 238 290 162 214 176 228 190 242 114 166 128 180 142 194 66 118 80 132 94 146 18 70 32 84 46 98 330 22 344 36 358 50 282 334 296 348 310 2 234 286 248 300 262 314 186 238 200 252 214 266 138 190 152 204 166 218 90 142 104 156 118 170 42 94 56 108 70 122 354 46 8 60 22 74 306 358 320 12 334 26 258 310 272 324 286 338 210 262 224 276 238 290 162 214 176 228 190 242 114 166 128 180 142 194 66 118 80 132 94
# ph3 = (360) 309 271 53 15 247 299 261 223 5 327 199 251 213 175 317 279 151 203 165 127 269 231 103 155 117 79 221 183 55 107 69 31 173 135 7 59 21 343 125 87 319 11 333 295 77 39 271 323 285 247 29 351 223 275 237 199 341 303 175 227 189 151 293 255 127 179 141 103 245 207 79 131 93 55 197 159 31 83 45 7 149 111 343 35 357 319 101 63 295 347 309 271 53 15 247 299 261 223 5 327 199 251 213 175 317 279 151 203 165 127 269 231 103 155 117 79 221 183 55 107 69 31 173 135 7 59 21 343 125 87 319 11 333 295 77 39 271 323 285 247 29 351 223 275 237 199 341 303 175 227 189 151 293 255 127 179 141 103 245 207 79 131 93 55 197 159 31 83 45 7 149 111 343 35 357 319 101 63 295 347 309 271 53 15 247 299 261 223 5 327 199 251 213 175 317 279 151 203 165 127 269 231 103 155 117 79 221 183 55 107 69 31 173 135 7 59 21 343 125 87 319 11 333 295 77 39 271 323 285 247 29 351 223 275 237 199 341 303 175 227 189 151 293 255 127 179 141 103 245 207 79 131 93 55 197 159 31 83 45 7 149 111 343 35 357 319 101 63 295 347 309 271 53 15 247 299 261 223 5 327 199 251 213 175 317 279 151 203 165 127 269 231 103 155 117 79 221 183 55 107

# %%
"""
Calibrate the T1 using a population inversion & recovery experiment.

This is implemented experimentally using t1_calibration
"""

sig_raw = nmr.Experiment(96,'expt9').load_tpc(normalize=False)
sig = sig_raw/abs(sig_raw[0])
tau = np.array([0.000005, 0.000050, 1.00000, 5.00000, 10.00000, 15.0000, 20.00000, 25.00000, 30.00000, 60])

p = np.polyfit(tau,-np.log((1-sig)/2), 1)
plt.plot(tau, tau*p[0] + p[1])
plt.scatter(tau,-np.log((1-sig)/2))
plt.show()

plt.scatter(tau,sig)
plt.plot(tau, 1-2*np.exp(-p[1])*np.exp(-tau*p[0]), label=1/p[0])
plt.legend()
plt.xlabel("Inversion recovery time (s)")
plt.ylabel("Normalized Signal")
plt.show()

print(5/p[0])
# Out:
# 93.69644901077528

# %%
sig_raw
# Out:
# array([-12599., -12235., -10824.,  -6420.,  -2132.,   1229.,   3740.,
#          5790.,   7375.,  11606.])

# %%
nmr.Experiment(183,folder='expt9').calibrate_framechange(phase_inc=1,offset=7,use_real=False)
# Out:
# Over-rotation angle is given by 2 deg.

# %%
"""
Calibrate the T1 using a population inversion & recovery experiment.

This is implemented experimentally using t1_calibration
"""

sig_raw = nmr.Experiment(75,'expt9').load_tpc(normalize=False)
sig = sig_raw/abs(sig_raw[0])
tau = np.array([0.000005, 1.00000, 5.00000, 10.00000, 15.0000, 20.00000, 25.00000, 30.00000, 60])

p = np.polyfit(tau,-np.log((1-sig)/2), 1)
plt.plot(tau, tau*p[0] + p[1])
plt.scatter(tau,-np.log((1-sig)/2))
plt.show()

plt.scatter(tau,sig)
plt.plot(tau, 1-2*np.exp(-p[1])*np.exp(-tau*p[0]), label=1/p[0])
plt.legend()
plt.xlabel("Inversion recovery time (s)")
plt.ylabel("Normalized Signal")
plt.show()

print(5/p[0])
# Out:
# 135.32053983684526

# %%
"""
Calibrate the T1 using a population inversion & recovery experiment.

This is implemented experimentally using t1_calibration
"""

sig_raw = nmr.Experiment(76,'expt9').load_tpc(normalize=False)
sig = sig_raw/abs(sig_raw[0])
tau = np.array([0.000005, 1.00000, 5.00000, 10.00000, 15.0000, 20.00000, 25.00000, 30.00000, 60])

p = np.polyfit(tau,-np.log((1-sig)/2), 1)
plt.plot(tau, tau*p[0] + p[1])
plt.scatter(tau,-np.log((1-sig)/2))
plt.show()

plt.scatter(tau,sig)
plt.plot(tau, 1-2*np.exp(-p[1])*np.exp(-tau*p[0]), label=1/p[0])
plt.legend()
plt.xlabel("Inversion recovery time (s)")
plt.ylabel("Normalized Signal")
plt.show()

print(5/p[0])
# Out:
# 138.14362356860195

# %%
"""
Calibrate the T1 using a population inversion & recovery experiment.

This is implemented experimentally using t1_calibration
"""

sig_raw = nmr.Experiment(77,'expt9').load_tpc(normalize=False)
sig = sig_raw[1:]/abs(sig_raw[0])
tau = np.array([1.00000, 5.00000, 10.00000, 15.0000, 20.00000, 25.00000, 30.00000, 60])

p = np.polyfit(tau,-np.log((1-sig)/2), 1)
plt.plot(tau, tau*p[0] + p[1])
plt.scatter(tau,-np.log((1-sig)/2))
plt.show()

plt.scatter(tau,sig)
plt.plot(tau, 1-2*np.exp(-p[1])*np.exp(-tau*p[0]), label=1/p[0])
plt.legend()
plt.xlabel("Inversion recovery time (s)")
plt.ylabel("Normalized Signal")
plt.show()

print(5/p[0])
# Out:
# 145.148758832578

# %%
"""
Calibrate the T1 using a population inversion & recovery experiment.

This is implemented experimentally using t1_calibration
"""

sig_raw = nmr.Experiment(78,'expt9').load_tpc(normalize=False)
sig = sig_raw[1:]/abs(sig_raw[0])
tau = np.array([10,20,30,60,90,120,150,240])

p = np.polyfit(tau,-np.log((1-sig)/2), 1)
plt.plot(tau, tau*p[0] + p[1])
plt.scatter(tau,-np.log((1-sig)/2))
plt.show()

plt.scatter(tau,sig)
plt.plot(tau, 1-2*np.exp(-p[1])*np.exp(-tau*p[0]), label=1/p[0])
plt.legend()
plt.xlabel("Inversion recovery time (s)")
plt.ylabel("Normalized Signal")
plt.show()

print(5/p[0])
# Out:
# 572.8673083711927

# %%
(300/-np.log((1-0.86)/2))
# Out:
# 112.81333748241619

# %%
(300/-np.log((1-0.86)/2))*5
# Out:
# 564.0666874120809

# %%
"""
Calibrate the T1 using a population inversion & recovery experiment.

This is implemented experimentally using t1_calibration
"""

sig_raw = nmr.Experiment(79,'expt9').load_tpc(normalize=False)
sig = sig_raw[:-1]/abs(sig_raw[-1])
tau = np.array([1, 10,20,30,60,90,120,150])

p = np.polyfit(tau,-np.log((1-sig)/2), 1)
plt.plot(tau, tau*p[0] + p[1])
plt.scatter(tau,-np.log((1-sig)/2))
plt.show()

plt.scatter(tau,sig)
plt.plot(tau, 1-2*np.exp(-p[1])*np.exp(-tau*p[0]), label=1/p[0])
plt.legend()
plt.xlabel("Inversion recovery time (s)")
plt.ylabel("Normalized Signal")
plt.show()

print(5/p[0])
# Out:
# 94.23450669146396

# %%
-np.log((1-sig)/2)
# Out:
# array([0.08997024, 0.54910116, 1.04889845, 1.55307216, 3.05026722,
#        4.5215548 , 6.14543339, 8.20685643])

# %%
sig_raw
# Out:
# array([-10623.,  -1988.,   3841.,   7401.,  11616.,  12552.,  12776.,
#         12824.,  12831.])

# %%
sig_raw_temp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 sig_raw_temp
#
# NameError: name 'sig_raw_temp' is not defined

# %%
print(nmr.PulseProgram.angle12(fc=5,n_max=50,xx=True))

# %%
print(nmr.PulseProgram.dtc_dis_int(180, 12, n_max=50))

# %%
print(nmr.PulseProgram.peng24(fc=6,n_max=50,xx=False))

# %%
print(nmr.PulseProgram.wahuha8(fc=10,n_max=50,xx=False))

# %%
arr = nmr.Experiment(84).offset_cal(use_spline=False,pad_factor=1)

# %%
arr*10**6

# %%
arr = nmr.Experiment(84).offset_cal(use_spline=True,pad_factor=2)

# %%
print(nmr.PulseProgram.cory48(fc=0,n_max=1,xx=True))

# %%
"""
; For DQ Loschmidt echo expts

define delay tau1
"tau1=d3-p1/2"
define delay tau2
"tau2=d3*(1-cnst1)-p1"
define delay tau3
"tau3=2*d3*(1+cnst1)-p1"

define delay tau1r
"tau1r=d3-p1/2"
define delay tau2r
"tau2r=d3*(1+cnst1)-p1"
define delay tau3r
"tau3r=2*d3*(1-cnst1)-p1"
"""
def to_str(lst):
    return ["{:10.8f}".format(val) for val in lst]

cnst1=[0.0, .02, .04, .06, .08, .10]

us = 10**-6
d3=5*us
p1=1.02*us
tau1 = [d3-p1/2 for c1 in cnst1]
tau2 = [d3*(1-c1)-p1 for c1 in cnst1]
tau3 = [2*d3*(1+c1)-p1 for c1 in cnst1]
tau1r = [d3-p1/2 for c1 in cnst1]
tau2r = [d3*(1+c1)-p1 for c1 in cnst1]
tau3r = [2*d3*(1-c1)-p1 for c1 in cnst1]

str_list = []

str_list.append("define list<delay> tau1 = {" + " ".join(to_str(tau1)) + "}")
str_list.append("define list<delay> tau2 = {" + " ".join(to_str(tau2)) + "}")
str_list.append("define list<delay> tau3 = {" + " ".join(to_str(tau3)) + "}")

str_list.append("define list<delay> tau1r = {" + " ".join(to_str(tau1r)) + "}")
str_list.append("define list<delay> tau2r = {" + " ".join(to_str(tau2r)) + "}")
str_list.append("define list<delay> tau3r = {" + " ".join(to_str(tau3r)) + "}")

print(f"\n".join(str_list))
